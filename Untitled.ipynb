# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns
from scipy import stats 
import pandas as pd 
import math
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("GDP_growth.csv")
df.rename(columns={'Time':'Year'},inplace=True)
df.head()
# Out:
#    Year   Exports       F_C_E  Forest_rents       GDP   G_F_C_E  \
# 0  1976  4.746082  102.978749      0.662683  5.661361  4.067941
# 1  1977  7.040752   93.817476      2.420676  2.673056  5.089239
# 2  1978  5.557663   98.376390      1.746745  7.073838  4.875571
# 3  1979  6.109219   98.484752      0.628412  4.801635  6.283769
# 4  1980  5.494284   97.949272      0.663666  0.819142  6.141041
#
#    Domestic_savings    Savings   Imports    Industry  Inflation  \
# 0         -2.978749  -0.840907  17.636193  14.449203 -17.630419
# 1          6.182524  10.039923  12.381446  16.729074  -3.210156
# 2          1.623610   5.704444  15.480852  14.309713  25.618886
# 3          1.515248   7.076282  15.797844  15.686455  12.564506
# 4          2.050728   8.332931  17.882947  20.116676  17.555067
#
#    Manufacturing  Gas_rents  Oil_rents  Remittance   Services  Unemployment
# 0       9.283923   0.098908   0.005781    0.185441  33.636340           NaN
# 1      11.226209   0.140857   0.006319    0.817261  34.372869           NaN
# 2       9.910996   0.073973   0.004246    0.869127  31.439979           NaN
# 3       9.861452   0.057794   0.007750    1.099476  31.861533           NaN
# 4      14.487485   0.096209   0.006261    1.867162  44.555666           NaN

# %%
df.isnull().sum()
# Out:
# Year                 0
# Exports              0
# F_C_E                0
# Forest_rents         2
# GDP                  0
# G_F_C_E              0
# Domestic_savings     0
# Savings              0
# Imports              0
# Industry             0
# Inflation            0
# Manufacturing        0
# Gas_rents            2
# Oil_rents            2
# Remittance           0
# Services             0
# Unemployment        32
# dtype: int64

# %%
# Preprossing
# Gas Rent null value replaced with mean
G=df['Gas_rents'].mean()
# Oill Rent null value replace by mean of all values
O=df['Oil_rents'].mean()
df['Oil_rents'].fillna(O,inplace=True)

# Forest rent
f=df['Forest_rents'].mean()
df['Forest_rents'].fillna(f,inplace=True)

df['Gas_rents'].fillna(G,inplace=True)
x=df["Unemployment"].median()
df["Unemployment"].fillna(x,inplace=True)

# %%
df.isnull().sum()
# Out:
# Year                0
# Exports             0
# F_C_E               0
# Forest_rents        0
# GDP                 0
# G_F_C_E             0
# Domestic_savings    0
# Savings             0
# Imports             0
# Industry            0
# Inflation           0
# Manufacturing       0
# Gas_rents           0
# Oil_rents           0
# Remittance          0
# Services            0
# Unemployment        0
# dtype: int64

# %%
df = round(df,2)
df

df.tail(3)
a=min(df.GDP)
b=max(df.GDP)
print(a,b)
# Out:
# 0.82 7.88

# %%
x2=df.Year

# %%
df.columns
# Out:
# Index(['Year', 'Exports', 'F_C_E', 'Forest_rents', 'GDP', 'G_F_C_E',
#        'Domestic_savings', 'Savings', 'Imports ', 'Industry', 'Inflation',
#        'Manufacturing', 'Gas_rents', 'Oil_rents', 'Remittance', 'Services',
#        'Unemployment'],
#       dtype='object')

# %%
df.shape
# Out:
# (48, 17)

# %% [markdown]
# ## Feature Scaling

# %%
data=df.drop('Year',axis=1)
df_norm=(data-data.min())/(data.max()-data.min())
# df=pd.concat(df_norm)
df_norm.head()
# Out:
#     Exports     F_C_E  Forest_rents       GDP   G_F_C_E  Domestic_savings  \
# 0  0.080549  1.000000      0.251064  0.685552  0.017778          0.000000
# 1  0.217184  0.697190      1.000000  0.262040  0.471111          0.302810
# 2  0.128878  0.847934      0.714894  0.885269  0.377778          0.152066
# 3  0.161695  0.851240      0.238298  0.563739  1.000000          0.148760
# 4  0.124702  0.833719      0.251064  0.000000  0.937778          0.166281
#
#     Savings  Imports   Industry  Inflation  Manufacturing  Gas_rents  \
# 0  0.000000  0.365538  0.006903   0.000000       0.000000   0.077519
# 1  0.262548  0.041846  0.119329   0.317062       0.149311   0.108527
# 2  0.157819  0.232615  0.000000   0.950967       0.048239   0.054264
# 3  0.191120  0.252308  0.068047   0.663808       0.044410   0.046512
# 4  0.221284  0.380308  0.286489   0.773747       0.398928   0.077519
#
#    Oil_rents  Remittance  Services  Unemployment
# 0   0.047619    0.000000  0.098788      0.593533
# 1   0.047619    0.060577  0.131567      0.593533
# 2   0.000000    0.065385  0.000000      0.593533
# 3   0.047619    0.087500  0.018859      0.593533
# 4   0.047619    0.161538  0.589133      0.593533

# %%
cor=df_norm.corr()
cor
# Out:
#                    Exports     F_C_E  Forest_rents       GDP   G_F_C_E  \
# Exports           1.000000 -0.673118     -0.427557  0.558539  0.490220
# F_C_E            -0.673118  1.000000      0.634542 -0.466708 -0.431936
# Forest_rents     -0.427557  0.634542      1.000000 -0.282417 -0.198238
# GDP               0.558539 -0.466708     -0.282417  1.000000  0.377314
# G_F_C_E           0.490220 -0.431936     -0.198238  0.377314  1.000000
# Domestic_savings  0.673118 -1.000000     -0.634542  0.466708  0.431936
# Savings           0.821787 -0.935990     -0.624094  0.475887  0.398556
# Imports           0.900669 -0.421372     -0.299451  0.525201  0.440890
# Industry          0.566254 -0.853378     -0.545403  0.478789  0.639913
# Inflation        -0.060355 -0.024599      0.054037 -0.012304  0.111390
# Manufacturing     0.466198 -0.799261     -0.508217  0.425525  0.589377
# Gas_rents         0.859564 -0.619216     -0.438521  0.461303  0.383671
# Oil_rents         0.837436 -0.451793     -0.304949  0.435010  0.278786
# Remittance        0.906742 -0.646181     -0.453757  0.435139  0.347506
# Services          0.746148 -0.879815     -0.736074  0.314195  0.299179
# Unemployment      0.461782 -0.298968     -0.090754  0.385218  0.489495
#
#                   Domestic_savings   Savings  Imports   Industry  Inflation  \
# Exports                   0.673118  0.821787  0.900669  0.566254  -0.060355
# F_C_E                    -1.000000 -0.935990 -0.421372 -0.853378  -0.024599
# Forest_rents             -0.634542 -0.624094 -0.299451 -0.545403   0.054037
# GDP                       0.466708  0.475887  0.525201  0.478789  -0.012304
# G_F_C_E                   0.431936  0.398556  0.440890  0.639913   0.111390
# Domestic_savings          1.000000  0.935990  0.421372  0.853378   0.024599
# Savings                   0.935990  1.000000  0.635070  0.786188   0.035462
# Imports                   0.421372  0.635070  1.000000  0.412759  -0.026636
# Industry                  0.853378  0.786188  0.412759  1.000000  -0.002700
# Inflation                 0.024599  0.035462 -0.026636 -0.002700   1.000000
# Manufacturing             0.799261  0.729824  0.332524  0.983142   0.060006
# Gas_rents                 0.619216  0.744044  0.726712  0.415649  -0.133859
# Oil_rents                 0.451793  0.675576  0.835946  0.320548  -0.060525
# Remittance                0.646181  0.865228  0.856574  0.532983  -0.003227
# Services                  0.879815  0.921550  0.561177  0.685543  -0.003134
# Unemployment              0.298968  0.330258  0.436920  0.366556  -0.082996
#
#                   Manufacturing  Gas_rents  Oil_rents  Remittance  Services  \
# Exports                0.466198   0.859564   0.837436    0.906742  0.746148
# F_C_E                 -0.799261  -0.619216  -0.451793   -0.646181 -0.879815
# Forest_rents          -0.508217  -0.438521  -0.304949   -0.453757 -0.736074
# GDP                    0.425525   0.461303   0.435010    0.435139  0.314195
# G_F_C_E                0.589377   0.383671   0.278786    0.347506  0.299179
# Domestic_savings       0.799261   0.619216   0.451793    0.646181  0.879815
# Savings                0.729824   0.744044   0.675576    0.865228  0.921550
# Imports                0.332524   0.726712   0.835946    0.856574  0.561177
# Industry               0.983142   0.415649   0.320548    0.532983  0.685543
# Inflation              0.060006  -0.133859  -0.060525   -0.003227 -0.003134
# Manufacturing          1.000000   0.302890   0.243101    0.464781  0.634366
# Gas_rents              0.302890   1.000000   0.810086    0.824914  0.729089
# Oil_rents              0.243101   0.810086   1.000000    0.882538  0.604773
# Remittance             0.464781   0.824914   0.882538    1.000000  0.775699
# Services               0.634366   0.729089   0.604773    0.775699  1.000000
# Unemployment           0.315058   0.393760   0.289605    0.359482  0.275024
#
#                   Unemployment
# Exports               0.461782
# F_C_E                -0.298968
# Forest_rents         -0.090754
# GDP                   0.385218
# G_F_C_E               0.489495
# Domestic_savings      0.298968
# Savings               0.330258
# Imports               0.436920
# Industry              0.366556
# Inflation            -0.082996
# Manufacturing         0.315058
# Gas_rents             0.393760
# Oil_rents             0.289605
# Remittance            0.359482
# Services              0.275024
# Unemployment          1.000000

# %% [markdown]
# ## Heatmap

# %%
#Heatmap
plt.figure(figsize=(10,12))            
annot=True
hemap=sns.heatmap(cor,vmin=-1,vmax=1,center=0,annot=annot)
hemap
#plt.savefig("HeadMap")
# Out:
# <Axes: >

# %% [markdown]
# ## Upper Trangular Matrix

# %%
mask = np.triu(np.ones_like(df_norm.corr()))

# %%
#upper trangular correlation matrix
plt.figure(figsize=(12
                    ,10))
dataplot = sns.heatmap(df_norm.corr(), mask=mask,cmap="spring",annot=True)
plt.show
plt.savefig("upper_trangular_matrix.png")

# %%
from sklearn import model_selection 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import r2_score,mean_squared_error,root_mean_squared_error,mean_absolute_error,median_absolute_error,mean_absolute_percentage_error

# %%
df_norm
df=pd.concat([x2,df_norm],axis=1)
df
round(df,2)
# Out:
#     Year  Exports  F_C_E  Forest_rents   GDP  G_F_C_E  Domestic_savings  \
# 0   1976     0.08   1.00          0.25  0.69     0.02              0.00
# 1   1977     0.22   0.70          1.00  0.26     0.47              0.30
# 2   1978     0.13   0.85          0.71  0.89     0.38              0.15
# 3   1979     0.16   0.85          0.24  0.56     1.00              0.15
# 4   1980     0.12   0.83          0.25  0.00     0.94              0.17
# 5   1981     0.10   0.41          0.20  0.91     0.16              0.59
# 6   1982     0.10   0.41          0.34  0.19     0.18              0.59
# 7   1983     0.13   0.50          0.23  0.43     0.12              0.50
# 8   1984     0.00   0.68          0.18  0.56     0.14              0.32
# 9   1985     0.12   0.42          0.09  0.36     0.00              0.58
# 10  1986     0.11   0.40          0.19  0.47     0.08              0.60
# 11  1987     0.09   0.44          0.15  0.42     0.05              0.56
# 12  1988     0.12   0.45          0.15  0.23     0.06              0.55
# 13  1989     0.13   0.40          0.14  0.29     0.05              0.60
# 14  1990     0.15   0.38          0.15  0.68     0.01              0.62
# 15  1991     0.19   0.42          0.15  0.38     0.05              0.58
# 16  1992     0.25   0.44          0.15  0.65     0.19              0.56
# 17  1993     0.34   0.49          0.11  0.55     0.41              0.51
# 18  1994     0.33   0.47          0.10  0.43     0.38              0.53
# 19  1995     0.45   0.47          0.11  0.61     0.27              0.53
# 20  1996     0.38   0.36          0.09  0.52     0.31              0.64
# 21  1997     0.42   0.33          0.06  0.52     0.39              0.67
# 22  1998     0.50   0.29          0.06  0.62     0.49              0.71
# 23  1999     0.50   0.28          0.06  0.55     0.45              0.72
# 24  2000     0.53   0.24          0.06  0.63     0.42              0.76
# 25  2001     0.60   0.22          0.06  0.60     0.36              0.78
# 26  2002     0.54   0.21          0.05  0.43     0.44              0.79
# 27  2003     0.48   0.23          0.05  0.56     0.49              0.77
# 28  2004     0.46   0.20          0.05  0.63     0.51              0.80
# 29  2005     0.66   0.21          0.04  0.81     0.51              0.79
# 30  2006     0.77   0.19          0.06  0.83     0.63              0.81
# 31  2007     0.81   0.22          0.11  0.88     0.59              0.78
# 32  2008     0.85   0.27          0.08  0.74     0.51              0.73
# 33  2009     0.81   0.23          0.07  0.60     0.47              0.77
# 34  2010     0.75   0.21          0.13  0.67     0.47              0.79
# 35  2011     0.99   0.22          0.12  0.80     0.48              0.78
# 36  2012     1.00   0.20          0.09  0.81     0.45              0.80
# 37  2013     0.96   0.17          0.06  0.74     0.48              0.83
# 38  2014     0.93   0.17          0.05  0.74     0.58              0.83
# 39  2015     0.83   0.17          0.06  0.81     0.61              0.83
# 40  2016     0.63   0.00          0.05  0.89     0.82              1.00
# 41  2017     0.56   0.01          0.03  0.82     0.88              0.99
# 42  2018     0.55   0.03          0.00  0.92     0.86              0.97
# 43  2019     0.58   0.01          0.00  1.00     0.98              0.99
# 44  2020     0.42   0.01          0.00  0.37     0.86              0.99
# 45  2021     0.43   0.06          0.00  0.87     0.82              0.94
# 46  2022     0.57   0.07          0.14  0.89     0.74              0.93
# 47  2023     0.58   0.05          0.14  0.70     0.73              0.95
#
#     Savings  Imports   Industry  Inflation  Manufacturing  Gas_rents  \
# 0      0.00      0.37      0.01       0.00           0.00       0.08
# 1      0.26      0.04      0.12       0.32           0.15       0.11
# 2      0.16      0.23      0.00       0.95           0.05       0.05
# 3      0.19      0.25      0.07       0.66           0.04       0.05
# 4      0.22      0.38      0.29       0.77           0.40       0.08
# 5      0.53      0.15      0.27       0.61           0.36       0.01
# 6      0.59      0.24      0.28       0.60           0.36       0.00
# 7      0.58      0.19      0.32       0.57           0.44       0.06
# 8      0.41      0.11      0.35       0.56           0.48       0.02
# 9      0.54      0.07      0.30       0.79           0.40       0.02
# 10     0.57      0.01      0.30       0.57           0.38       0.11
# 11     0.57      0.00      0.26       0.63           0.32       0.11
# 12     0.56      0.03      0.28       0.55           0.32       0.09
# 13     0.56      0.07      0.27       0.57           0.28       0.16
# 14     0.58      0.08      0.29       0.53           0.30       0.19
# 15     0.56      0.03      0.34       0.45           0.36       0.14
# 16     0.55      0.04      0.37       0.44           0.39       0.16
# 17     0.52      0.15      0.43       0.39           0.47       0.19
# 18     0.56      0.13      0.45       0.47           0.50       0.22
# 19     0.55      0.35      0.46       0.54           0.51       0.25
# 20     0.58      0.29      0.36       0.81           0.36       0.23
# 21     0.61      0.25      0.37       0.47           0.37       0.21
# 22     0.64      0.27      0.41       0.49           0.43       0.25
# 23     0.66      0.30      0.40       0.47           0.39       0.33
# 24     0.69      0.32      0.39       0.46           0.36       0.53
# 25     0.71      0.43      0.41       0.46           0.38       0.54
# 26     0.76      0.30      0.42       0.47           0.39       0.69
# 27     0.75      0.28      0.40       0.52           0.37       0.71
# 28     0.78      0.25      0.42       0.49           0.40       0.76
# 29     0.80      0.51      0.44       0.49           0.42       0.90
# 30     0.87      0.62      0.48       0.52           0.46       1.00
# 31     0.90      0.69      0.50       0.53           0.51       0.60
# 32     0.92      0.82      0.51       0.56           0.52       0.55
# 33     0.96      0.70      0.54       0.54           0.55       0.66
# 34     0.96      0.62      0.53       0.54           0.52       0.70
# 35     0.94      0.97      0.53       0.56           0.51       0.81
# 36     1.00      1.00      0.54       0.57           0.51       0.83
# 37     0.98      0.93      0.59       0.55           0.55       0.60
# 38     0.93      0.85      0.59       0.51           0.56       0.57
# 39     0.91      0.80      0.62       0.52           0.58       0.49
# 40     0.92      0.35      0.83       1.00           0.85       0.38
# 41     0.87      0.34      0.84       0.50           0.83       0.40
# 42     0.88      0.50      0.87       0.52           0.88       0.39
# 43     0.90      0.42      0.91       0.47           0.91       0.40
# 44     0.92      0.25      0.92       0.47           0.87       0.36
# 45     0.89      0.33      0.94       0.48           0.92       0.38
# 46     0.84      0.57      0.97       0.50           0.96       0.36
# 47     0.86      0.38      1.00       0.54           1.00       0.36
#
#     Oil_rents  Remittance  Services  Unemployment
# 0        0.05        0.00      0.10          0.59
# 1        0.05        0.06      0.13          0.59
# 2        0.00        0.07      0.00          0.59
# 3        0.05        0.09      0.02          0.59
# 4        0.05        0.16      0.59          0.59
# 5        0.00        0.16      0.64          0.59
# 6        0.00        0.25      0.66          0.59
# 7        0.05        0.33      0.64          0.59
# 8        0.10        0.24      0.46          0.26
# 9        0.05        0.20      0.58          0.25
# 10       0.05        0.24      0.61          0.01
# 11       0.05        0.28      0.63          0.59
# 12       0.05        0.26      0.67          0.59
# 13       0.05        0.23      0.71          0.00
# 14       0.10        0.22      0.69          0.59
# 15       0.05        0.22      0.58          0.30
# 16       0.05        0.26      0.58          0.59
# 17       0.05        0.27      0.66          0.59
# 18       0.10        0.31      0.67          0.59
# 19       0.05        0.29      0.61          0.59
# 20       0.10        0.26      0.84          0.37
# 21       0.10        0.29      0.83          0.59
# 22       0.05        0.29      0.83          0.59
# 23       0.10        0.32      0.84          0.59
# 24       0.19        0.34      0.86          0.54
# 25       0.24        0.36      0.86          0.59
# 26       0.38        0.48      0.90          0.59
# 27       0.33        0.49      0.94          0.79
# 28       0.43        0.51      0.96          0.59
# 29       0.43        0.58      0.96          0.77
# 30       0.48        0.71      0.96          0.62
# 31       0.71        0.77      0.96          0.59
# 32       1.00        0.92      0.96          0.59
# 33       0.38        0.97      0.98          0.94
# 34       0.52        0.89      0.99          0.57
# 35       0.71        0.88      0.97          0.59
# 36       0.81        1.00      0.97          0.59
# 37       0.67        0.87      0.99          0.81
# 38       0.48        0.82      1.00          0.59
# 39       0.24        0.74      1.00          0.59
# 40       0.14        0.47      0.89          0.79
# 41       0.24        0.42      0.90          0.80
# 42       0.29        0.45      0.87          0.59
# 43       0.19        0.48      0.87          0.59
# 44       0.10        0.54      0.90          0.59
# 45       0.14        0.49      0.89          0.59
# 46       0.24        0.43      0.88          1.00
# 47       0.24        0.49      0.88          0.59

# %% [markdown]
# ## Multiple linear Regression:

# %%
X = df.drop("GDP",axis=1)
y = df.GDP

# %%
X.shape,y.shape
# Out:
# ((48, 16), (48,))

# %%
xtrain,xtest,ytrain,ytest=model_selection.train_test_split(X,y,test_size=0.2,random_state=17)

# %%
lm=LinearRegression()
lm.fit(X,y)
print(lm.intercept_)
print(lm.coef_)
# Out:
# -100.66765277021844
# [ 0.05141925 -0.21651406 -0.36477606 -0.44244668 -0.02786447  0.36477606
#   0.85375571  0.74360932 -7.11887428 -0.24599469  5.03623231  0.24229279
#   0.09568682 -1.14220108 -1.38394639  0.18586908]

# %%
lm_train_score=lm.score(xtrain,ytrain)
lm_test_score=lm.score(xtest,ytest)
print("train score:{}".format(lm_train_score))
print("test score:{}".format(lm_test_score))
# Out:
# train score:0.6860181754424344
# test score:0.692838052025699

# %%
y_prediction=lm.predict(xtest)
r2_score(ytest,y_prediction)
# Out:
# 0.692838052025699

# %%
print("Root Mean squared error for train data:{}".format(sqrt(mean_squared_error(ytrain,lm.predict(xtrain)))))
print("Mean absulate error for train data:{}".format(mean_absolute_error(ytrain,lm.predict(xtrain))))
print("Median absulate error for train data:{}".format(median_absolute_error(ytrain,lm.predict(xtrain))))
# Out:
# Root Mean squared error for train data:0.12295485627058886
# Mean absulate error for train data:0.09101604719041323
# Median absulate error for train data:0.07916049280239021

# %%
# Prediction next five year GDP
y=y_prediction[:5]
print('Prediction next five year GDP:{}'.format(y))
# Out:
# Prediction next five year GDP:[0.94109658 0.84808814 0.49253263 0.76958126 0.5092887 ]

# %%
import numpy
print(a,b)
for i in y:
    GDP=i*(b-a)+a
    print(round(GDP,2))
# Out:
# 0.82 7.88
# 7.46
# 6.81
# 4.3
# 6.25
# 4.42

# %% [markdown]
# ## Hyperparameter Tuning for the Ridge Regression

# %%
from sklearn.linear_model import Ridge
from math import sqrt
from sklearn.metrics import r2_score,mean_squared_error,root_mean_squared_error,mean_absolute_error,median_absolute_error
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score


RidgeRegression = Ridge()
Parameters = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
ridgeRegressor = GridSearchCV(RidgeRegression,Parameters, cv=5)
ridgeRegressor.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 100]})

# %%
print(ridgeRegressor.best_estimator_)
# Out:
# Ridge(alpha=35)

# %%
model_2=Ridge(alpha=35)
model_2.fit(xtrain,ytrain)
# Out:
# Ridge(alpha=35)

# %%
train_score=model_2.score(xtrain,ytrain)
test_score=model_2.score(xtest,ytest)
print(train_score,test_score)
# Out:
# 0.2615318421251195 0.11017102822452929

# %%
y_pred_2=model_2.predict(xtest)

# %%
r2_score(ytest,y_pred_2)
# Out:
# 0.11017102822452929

# %%
y_pred_2[:5]
# Out:
# array([0.76913985, 0.71823697, 0.53328419, 0.64782493, 0.57396505])

# %%
print("Mean squared error for train data:{}".format(sqrt(mean_squared_error(ytrain,model_2.predict(xtrain)))))
print("Mean absulate error for train data:{}".format(mean_absolute_error(ytrain,model_2.predict(xtrain))))
print("Median absulate error for train data:{}".format(median_absolute_error(ytrain,model_2.predict(xtrain))))
# Out:
# Mean squared error for train data:0.18856423297956706
# Mean absulate error for train data:0.14122726031378396
# Median absulate error for train data:0.10334946543914586

# %%
# Prediction next five year GDP
y_ridge=y_pred_2[:5]
print('Prediction next five year GDP:{}'.format(y_ridge))
# Out:
# Prediction next five year GDP:[0.76913985 0.71823697 0.53328419 0.64782493 0.57396505]

# %%
print(a,b)
for i in y_ridge:
    GDP=i*(b-a)+a
    print(round(GDP,2))
# Out:
# 0.82 7.88
# 6.25
# 5.89
# 4.58
# 5.39
# 4.87

# %% [markdown]
# ## Hyperparameter Tuning for Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV

# %%
lasso_params = {'alpha':[0.02, 0.024, 0.025, 0.026, 0.03,0.05,0.06,0.07,0.08,1,2,3],
               'selection':['cyclic', 'random']
               }
lasso_model=GridSearchCV(Lasso(),lasso_params)
lasso_model.fit(xtrain,ytrain)
print(lasso_model.best_estimator_)
# Out:
# Lasso(alpha=0.02)

# %%
lasso_model_2=Lasso(alpha=0.02)
lasso_model_2.fit(xtrain,ytrain)
# Out:
# Lasso(alpha=0.02)

# %%
train_score=lasso_model_2.score(xtrain,ytrain)

test_score=lasso_model_2.score(xtest,ytest)
print(train_score)
print(test_score)
# Out:
# 0.23504545228871843
# 0.1494397908905707

# %%
y_pred=lasso_model_2.predict(xtest)
r2_score(ytest,y_pred)
# Out:
# 0.1494397908905707

# %%
# Next five year prediction
y1=y_pred[:5]

# %%
print(a,b)
for i in y1:
    GDP=i*(b-a)+a
    print(round(GDP,2))
# Out:
# 0.82 7.88
# 6.28
# 5.94
# 4.62
# 5.34
# 4.9

# %% [markdown]
# ## Parameter tuning for SVR

# %%
from sklearn.svm import SVR

from sklearn.model_selection import GridSearchCV 

param_grid = {'C': [0.1, 1, 10, 100, 1000], 
			'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
			'kernel': ['rbf']} 

grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3) 
sv_model=grid.fit(xtrain, ytrain)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.057 total time=   0.0s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.122 total time=   0.0s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.405 total time=   0.0s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.069 total time=   0.0s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.404 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.187 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.328 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.136 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.004 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.507 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.278 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.378 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.362 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.336 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.216 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.103 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.477 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.323 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.630 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.150 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.027 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.297 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.246 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.107 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.225 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.078 total time=   0.0s
# [CV 2/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.421 total time=   0.0s
# [CV 3/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.476 total time=   0.0s
# [CV 4/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.047 total time=   0.0s
# [CV 5/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.488 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.037 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-1.261 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.444 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.935 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.966 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.223 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.872 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.322 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.665 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.418 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.100 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.899 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.552 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.494 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.264 total time=   0.0s
# [CV 1/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.041 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.688 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.463 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.725 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.015 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.078 total time=   0.0s
# [CV 2/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.421 total time=   0.0s
# [CV 3/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.476 total time=   0.0s
# [CV 4/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.047 total time=   0.0s
# [CV 5/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.488 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.296 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-2.176 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.415 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-1.816 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.901 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.140 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-1.027 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.347 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.809 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.642 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.262 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.982 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.499 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.201 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.197 total time=   0.0s
# [CV 1/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.133 total time=   0.0s
# [CV 2/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.794 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.635 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.747 total time=   0.0s
# [CV 5/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.157 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.078 total time=   0.0s
# [CV 2/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.421 total time=   0.0s
# [CV 3/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.476 total time=   0.0s
# [CV 4/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.047 total time=   0.0s
# [CV 5/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.488 total time=   0.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.444 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-2.176 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.716 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-1.827 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.901 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.198 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-1.085 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.403 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.398 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.725 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.105 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.973 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.057 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.556 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.360 total time=   0.0s
# [CV 1/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.089 total time=   0.0s
# [CV 2/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.859 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.602 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.544 total time=   0.0s
# [CV 5/5] END ..C=100, gamma=0.0001, kernel=rbf;, score=-0.579 total time=   0.0s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.078 total time=   0.0s
# [CV 2/5] END ......C=1000, gamma=1, kernel=rbf;, score=-0.421 total time=   0.0s
# [CV 3/5] END ......C=1000, gamma=1, kernel=rbf;, score=-0.476 total time=   0.0s
# [CV 4/5] END ......C=1000, gamma=1, kernel=rbf;, score=-0.047 total time=   0.0s
# [CV 5/5] END ......C=1000, gamma=1, kernel=rbf;, score=-0.488 total time=   0.0s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.444 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.1, kernel=rbf;, score=-2.176 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.1, kernel=rbf;, score=-0.716 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.1, kernel=rbf;, score=-1.827 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.1, kernel=rbf;, score=-0.901 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.01, kernel=rbf;, score=-0.378 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.01, kernel=rbf;, score=-1.054 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.01, kernel=rbf;, score=-0.427 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.011 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.01, kernel=rbf;, score=-0.676 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.001, kernel=rbf;, score=-0.208 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.001, kernel=rbf;, score=-0.881 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.001, kernel=rbf;, score=-0.286 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.001, kernel=rbf;, score=-0.251 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.001, kernel=rbf;, score=-0.874 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.055 total time=   0.0s
# [CV 2/5] END .C=1000, gamma=0.0001, kernel=rbf;, score=-1.080 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.033 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.047 total time=   0.0s
# [CV 5/5] END .C=1000, gamma=0.0001, kernel=rbf;, score=-0.767 total time=   0.0s

# %%
print(sv_model.best_estimator_)
# Out:
# SVR(C=1, gamma=0.0001)

# %%
sv_model_2=SVR(C=1,gamma=0.0001,kernel='rbf',)
sv_model_2.fit(xtrain,ytrain)
# Out:
# SVR(C=1, gamma=0.0001)

# %%
y_pred_sv=sv_model_2.predict(xtest)
r2_score(ytest,y_pred_sv)
# Out:
# 0.2502891372942745

# %%
sv_train_score=sv_model_2.score(xtrain,ytrain)
sv_test_score=sv_model_2.score(xtest,ytest)
print("train score:{}".format(sv_train_score))
print("test score:{}".format(sv_test_score))
# Out:
# train score:0.24170140716131794
# test score:0.2502891372942745

# %%
print("Mean squared error for train data:{}".format(sqrt(mean_squared_error(ytrain,sv_model_2.predict(xtrain)))))
print("Mean absulate error for train data:{}".format(mean_absolute_error(ytrain,sv_model_2.predict(xtrain))))
print("Median absulate error for train data:{}".format(median_absolute_error(ytrain,sv_model_2.predict(xtrain))))
# Out:
# Mean squared error for train data:0.19107926281003768
# Mean absulate error for train data:0.14256526782300027
# Median absulate error for train data:0.1000619864189165

# %%
# Next five year prediction
y2=y_pred_sv[:5]

# %%
print(a,b)
for i in y2:
    GDP=i*(b-a)+a
    print(round(GDP,2))
# Out:
# 0.82 7.88
# 6.41
# 6.05
# 4.56
# 5.37
# 4.87

# %% [markdown]
# ## Hyperparameter Tuning for Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score

# %%
param_grid = { 
	'n_estimators': [25, 50, 100, 150], 
	'max_features': ['sqrt', 'log2', None], 
	'max_depth': [3, 6, 9,10,15,25,30], 
	'max_leaf_nodes': [3, 6, 9], 
}

# %%
# from sklearn.metrics import 
random_search =GridSearchCV(RandomForestRegressor(),param_grid) 
random_search.fit(xtrain, ytrain) 
print(random_search.best_estimator_)
# Out:
# RandomForestRegressor(max_depth=9, max_features='sqrt', max_leaf_nodes=3)

# %%
model_rand=RandomForestRegressor(max_depth=9,
                                 max_features='sqrt',
                                 max_leaf_nodes=3,
                                 n_estimators=25
                            
                                 )
model_rand.fit(xtrain, ytrain) 
y_pred_rand = model_rand.predict(xtest)
r2_score(ytest,y_pred_rand)
# Out:
# -0.4657003109816913

# %%
train_score=model_rand.score(xtrain,ytrain)
test_score=model_rand.score(xtest,ytest)
print("train score:{}".format(train_score))
print("test score:{}".format(test_score))
# Out:
# train score:0.5182255792066853
# test score:-0.4657003109816913

# %%
print("Root Mean squared error for train data:{}".format(sqrt(mean_squared_error(ytrain, model_rand.predict(xtrain)))))
print("Mean absulate error for train data:{}".format(mean_absolute_error(ytrain,model_rand.predict(xtrain))))
print("Median absulate error for train data:{}".format(median_absolute_error(ytrain,model_rand.predict(xtrain))))
# Out:
# Root Mean squared error for train data:0.15230539981712465
# Mean absulate error for train data:0.11186362133004267
# Median absulate error for train data:0.07390062926466578

# %%
# Next five GDP prediction
y3=y_pred_rand[:5]

# %%
print(a,b)
for i in y3:
    GDP=i*(b-a)+a
    print(round(GDP,2))
# Out:
# 0.82 7.88
# 5.91
# 5.72
# 3.94
# 5.62
# 4.48

# %% [markdown]
# ## Hyperparameter Tuning for GradientBoost regression

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

# %%
para_grid={
    'n_estimators': [ 100, 200, 300, 400,500, 600, 700, 800, 900, 1000,1100, 1200],
    'min_samples_split': [2,4,8],
    'learning_rate': [0.01,0.1,1],
    'max_features': [ 'auto', 'sqrt', 'log2'],
    'max_depth': [5, 10, 15, 20, 25, 30]
}

# %%
gb_model = GridSearchCV(GradientBoostingRegressor(),para_grid,cv=5)
gb_model.fit(xtrain,ytrain)
print(gb_model.best_estimator_)
# Out:
# GradientBoostingRegressor(learning_rate=1, max_depth=25, max_features='log2',
#                           n_estimators=400)

# %%
gb_model_2=GradientBoostingRegressor(
                                    learning_rate=1,
                                     max_depth=25,
                                     max_features='log2',
                                    n_estimators=400
                                     
                                     )
gb_model_2.fit(xtrain,ytrain)
y_gb_pred=gb_model_2.predict(xtest)
r2_score(ytest,y_gb_pred)
# Out:
# -0.9179840034330444

# %%
train_score=gb_model_2.score(xtrain,ytrain)
test_score=gb_model_2.score(xtest,ytest)
print("train_score:{:.2f}".format(train_score))
print("train_score:{:.2f}".format(test_score))
# Out:
# train_score:1.00
# train_score:-0.92

# %%
print("Root Mean squared error for train data:{}".format(sqrt(mean_squared_error(ytrain, gb_model_2.predict(xtrain)))))

print("Mean absoulute error for test data:{}".format(sqrt(mean_absolute_error(ytrain, gb_model_2.predict(xtrain)))))
print("Median absulate error for train data:{}".format(median_absolute_error(ytrain,gb_model_2.predict(xtrain))))
# Out:
# Root Mean squared error for train data:1.1028771494284027e-17
# Mean absoulute error for test data:1.7092701921904649e-09
# Median absulate error for train data:0.0

# %%
# Next five GDP prediction
y4=y_gb_pred[:5]

# %%
print(a,b)
for i in y4:
    GDP=i*(b-a)+a
    print(GDP)
# Out:
# 0.82 7.88
# 5.78
# 7.32
# 2.13
# 5.08
# 4.5200000000000005

# %% [markdown]
# ## Hyperparameter Tuning For Adaboost

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV

param_dist = {
 'n_estimators': [50, 100,150,200,500],
 'learning_rate' : [0.01,0.05,0.1,0.3,1],
 'loss' : ['linear', 'square', 'exponential']
 }

# %%
rand_search = GridSearchCV(AdaBoostRegressor(),param_dist,cv=5)
rand_search.fit(xtrain,ytrain)
print(rand_search.best_estimator_)
# Out:
# AdaBoostRegressor(learning_rate=0.01)

# %%
random_model=AdaBoostRegressor(learning_rate=0.01
                               
                               
                            
                              )
random_model.fit(xtrain,ytrain)
y_rand_pred=random_model.predict(xtest)
r2_score(ytest,y_rand_pred)
# Out:
# -0.05467741599930931

# %%
train_score=random_model.score(xtrain,ytrain)
test_score=random_model.score(xtest,ytest)
print("train_score:{:.2f}".format(train_score))
print("train_score:{:.2f}".format(test_score))
# Out:
# train_score:0.89
# train_score:-0.05

# %%
print("Root Mean squared error for train data:{}".format(sqrt(mean_squared_error(ytrain, random_model.predict(xtrain)))))
print("Mean absolute error for test data:{}".format((mean_absolute_error(ytrain, random_model.predict(xtrain)))))
print("Median absulate error for train data:{}".format(median_absolute_error(ytrain,random_model.predict(xtrain))))
# Out:
# Root Mean squared error for train data:0.07303919620385904
# Mean absolute error for test data:0.05682078757399538
# Median absulate error for train data:0.04040874140024281

# %%
y5=y_rand_pred[:5]

# %%
print(a,b)
for i in y5:
    GDP=i*(b-a)+a
    print(GDP)
# Out:
# 0.82 7.88
# 6.101111111111111
# 6.4035714285714285
# 3.7828571428571434
# 5.2250000000000005
# 4.751666666666666
